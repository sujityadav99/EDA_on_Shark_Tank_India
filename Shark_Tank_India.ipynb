# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset : Shark Tank India

# %%
df = pd.read_csv('Shark_Tank_India_S1.csv')
df #dataset
# Out:
#      episode_number  startup_number           brand_name  \
# 0                 1               1  BluePine Industries
# 1                 1               2        Booz scooters
# 2                 1               3  Heart up my Sleeves
# 3                 2               4           Tagz Foods
# 4                 2               5       Head and Heart
# ..              ...             ...                  ...
# 116              35             117         Elcare India
# 117              36             118             Sneakare
# 118              36             119         French Crown
# 119              36             120       Store My Goods
# 120              36             121             Devnagri
#
#                                        description  deal_offered  \
# 0                                     Frozen Momos             1
# 1    Renting e-bike for mobility in private spaces             1
# 2                               Detachable Sleeves             1
# ...

# %% [markdown]
# ### top 5 entries

# %%
df.head()
# Out:
#    episode_number  startup_number           brand_name  \
# 0               1               1  BluePine Industries
# 1               1               2        Booz scooters
# 2               1               3  Heart up my Sleeves
# 3               2               4           Tagz Foods
# 4               2               5       Head and Heart
#
#                                      description  deal_offered  \
# 0                                   Frozen Momos             1
# 1  Renting e-bike for mobility in private spaces             1
# 2                             Detachable Sleeves             1
# 3                           Healthy Potato Chips             1
# 4                       Brain Development Course             0
#
#    startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 0                      50.0                     5.0                1000.00
# 1                      40.0                    15.0                 266.67
# ...

# %% [markdown]
# ### last 5 entries

# %%
df.tail()
# Out:
#      episode_number  startup_number      brand_name  \
# 116              35             117    Elcare India
# 117              36             118        Sneakare
# 118              36             119    French Crown
# 119              36             120  Store My Goods
# 120              36             121        Devnagri
#
#                          description  deal_offered  startup_ask_amount_lakhs  \
# 116             Carenting for Elders             0                     100.0
# 117  Shoe care and storage solutions             1                      20.0
# 118                Clothing Industry             0                     150.0
# 119                Storage solutions             1                     100.0
# 120             Translation platform             0                     100.0
#
#      startup_ask_percentage  startup_ask_valuation  deal_amount_lakhs  \
# 116                    2.50                 4000.0                0.0
# ...

# %%
df.shape
# Out:
# (121, 32)

# %% [markdown]
# ### Dataset abstract summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   episode_number            121 non-null    int64
#  1   startup_number            121 non-null    int64
#  2   brand_name                121 non-null    object
#  3   description               121 non-null    object
#  4   deal_offered              121 non-null    int64
#  5   startup_ask_amount_lakhs  121 non-null    float64
#  6   startup_ask_percentage    121 non-null    float64
#  7   startup_ask_valuation     121 non-null    float64
#  8   deal_amount_lakhs         121 non-null    float64
#  9   deal_equity               121 non-null    float64
#  10  deal_valuation            121 non-null    float64
#  11  loan_element_present      121 non-null    int64
#  12  loan_amount               121 non-null    int64
# ...

# %% [markdown]
# ### Fetch all column names

# %%
df.columns
# Out:
# Index(['episode_number', 'startup_number', 'brand_name', 'description',
#        'deal_offered', 'startup_ask_amount_lakhs', 'startup_ask_percentage',
#        'startup_ask_valuation', 'deal_amount_lakhs', 'deal_equity',
#        'deal_valuation', 'loan_element_present', 'loan_amount',
#        'rannvijay_present', 'abish_present', 'aman_present', 'aman_invested',
#        'anupam_present', 'anupam_invested', 'ashneer_present',
#        'ashneer_invested', 'ghazal_present', 'ghazal_invested',
#        'namita_present', 'namita_invested', 'peyush_present',
#        'peyush_invested', 'vineeta_present', 'vineeta_invested',
#        'sharks_offering', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
df.columns.unique()
# Out:
# Index(['episode_number', 'startup_number', 'brand_name', 'description',
#        'deal_offered', 'startup_ask_amount_lakhs', 'startup_ask_percentage',
#        'startup_ask_valuation', 'deal_amount_lakhs', 'deal_equity',
#        'deal_valuation', 'loan_element_present', 'loan_amount',
#        'rannvijay_present', 'abish_present', 'aman_present', 'aman_invested',
#        'anupam_present', 'anupam_invested', 'ashneer_present',
#        'ashneer_invested', 'ghazal_present', 'ghazal_invested',
#        'namita_present', 'namita_invested', 'peyush_present',
#        'peyush_invested', 'vineeta_present', 'vineeta_invested',
#        'sharks_offering', 'amount_per_shark', 'equity_per_shark'],
#       dtype='object')

# %%
df.columns.nunique()
# Out:
# 32

# %% [markdown]
# ### checking missing entries from dataset

# %%
# missing entries
df.isna().sum()
# Out:
# episode_number              0
# startup_number              0
# brand_name                  0
# description                 0
# deal_offered                0
# startup_ask_amount_lakhs    0
# startup_ask_percentage      0
# startup_ask_valuation       0
# deal_amount_lakhs           0
# deal_equity                 0
# deal_valuation              0
# loan_element_present        0
# loan_amount                 0
# rannvijay_present           0
# abish_present               0
# aman_present                0
# aman_invested               0
# anupam_present              0
# anupam_invested             0
# ashneer_present             0
# ashneer_invested            0
# ghazal_present              0
# ghazal_invested             0
# namita_present              0
# namita_invested             0
# peyush_present              0
# peyush_invested             0
# vineeta_present             0
# vineeta_invested            0
# sharks_offering             0
# amount_per_shark            0
# ...

# %% [markdown]
# ### Conclusion: Here no missing values

# %% [markdown]
# ### Total No of startup_number participated

# %%
a = df.startup_number.size

# %%
print('Total numbers of startups :- ',a)
# Out:
# Total numbers of startups :-  121

# %% [markdown]
# ### Total numbers of episode in season 1

# %%
df.episode_number.nunique()
# Out:
# 36

# %% [markdown]
# ### Total numbers of deals offered in season

# %%
df.deal_offered.sum()
# Out:
# 68

# %%
print('Total number of deals offered in season 1:-',df.deal_offered.sum())
# Out:
# Total number of deals offered in season 1:- 68

# %% [markdown]
# ### Total investment in all the startups by all the sharks

# %%
total_investment=df.deal_amount_lakhs.sum()
total_investment
# Out:
# 3863.00106

# %%
df.deal_amount_lakhs.sum()
# Out:
# 3863.00106

# %%
print('Total investment in all the startups by all the sharks:',total_investment,'lakhs')
print('Total investment in all the startups by all the sharks:',total_investment/100,' crore')
# Out:
# Total investment in all the startups by all the sharks: 3863.00106 lakhs
# Total investment in all the startups by all the sharks: 38.6300106  crore

# %% [markdown]
# ### Max deal amount offered to which brand

# %%
df.sort_values(by='deal_amount_lakhs').tail(1)
# Out:
#     episode_number  startup_number     brand_name description  deal_offered  \
# 50              17              51  Aas Vidyalaya  EdTech App             1
#
#     startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 50                     150.0                     3.0                 5000.0
#
#     deal_amount_lakhs  deal_equity  ...  ghazal_invested  namita_present  \
# 50              150.0         15.0  ...                0               1
#
#     namita_invested  peyush_present  peyush_invested  vineeta_present  \
# 50                1               1                1                0
#
#     vineeta_invested  sharks_offering  amount_per_shark  equity_per_shark
# 50                 0                3              50.0               5.0
#
# [1 rows x 32 columns]

# %%
df.nlargest(1,'deal_amount_lakhs')
# Out:
#     episode_number  startup_number     brand_name description  deal_offered  \
# 50              17              51  Aas Vidyalaya  EdTech App             1
#
#     startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 50                     150.0                     3.0                 5000.0
#
#     deal_amount_lakhs  deal_equity  ...  ghazal_invested  namita_present  \
# 50              150.0         15.0  ...                0               1
#
#     namita_invested  peyush_present  peyush_invested  vineeta_present  \
# 50                1               1                1                0
#
#     vineeta_invested  sharks_offering  amount_per_shark  equity_per_shark
# 50                 0                3              50.0               5.0
#
# [1 rows x 32 columns]

# %%
max_deal=df.deal_amount_lakhs.max()
max_deal
# Out:
# 150.0

# %%
df.groupby('deal_amount_lakhs').get_group(max_deal)
# Out:
#     episode_number  startup_number     brand_name description  deal_offered  \
# 50              17              51  Aas Vidyalaya  EdTech App             1
#
#     startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 50                     150.0                     3.0                 5000.0
#
#     deal_amount_lakhs  deal_equity  ...  ghazal_invested  namita_present  \
# 50              150.0         15.0  ...                0               1
#
#     namita_invested  peyush_present  peyush_invested  vineeta_present  \
# 50                1               1                1                0
#
#     vineeta_invested  sharks_offering  amount_per_shark  equity_per_shark
# 50                 0                3              50.0               5.0
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Highest equity offered by which brand

# %%
df.nlargest(1,'deal_equity')
# Out:
#     episode_number  startup_number     brand_name description  deal_offered  \
# 65              21              66  Sid07 Designs  Inventions             1
#
#     startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 65                      47.0                    10.0                  470.0
#
#     deal_amount_lakhs  deal_equity  ...  ghazal_invested  namita_present  \
# 65               25.0         75.0  ...                0               0
#
#     namita_invested  peyush_present  peyush_invested  vineeta_present  \
# 65                0               1                1                1
#
#     vineeta_invested  sharks_offering  amount_per_shark  equity_per_shark
# 65                 0                1              25.0              75.0
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Maximum startup ask amount brand

# %%
a= df.sort_values(by='startup_ask_amount_lakhs',ascending=False)
a.loc[:,['brand_name','startup_ask_amount_lakhs']].head(5)
# Out:
#            brand_name  startup_ask_amount_lakhs
# 30         Gopal's 56                   30000.0
# 96   Shades of Spring                     300.0
# 103   Experential Etc                     200.0
# 50      Aas Vidyalaya                     150.0
# 80             Alpino                     150.0

# %% [markdown]
# ### Number of brand in which  2 to 5 sharks have invested

# %%
s=df[(df.sharks_offering>=3)&(df.sharks_offering<=5)].count().sharks_offering
s
# Out:
# 24

# %%
a=df[(df.sharks_offering>=2)&(df.sharks_offering<=5)]
a
# Out:
#      episode_number  startup_number                      brand_name  \
# 0                 1               1             BluePine Industries
# 1                 1               2                   Booz scooters
# 2                 1               3             Heart up my Sleeves
# 9                 4              10                           Cosiq
# 11                4              12                          Bummer
# 12                5              13                     Revamp Moto
# 15                6              16                     Skippi Pops
# 18                7              19              Raising Superstars
# 21                8              22                    Beyond Snack
# 22                8              23  Vivalyf Innovations- Easy Life
# 24                9              25                           Altor
# 25                9              26                           Ariro
# 27               10              28                         Nuutjob
# ...

# %%
a[['brand_name','sharks_offering']]
# Out:
#                          brand_name  sharks_offering
# 0               BluePine Industries                3
# 1                     Booz scooters                2
# 2               Heart up my Sleeves                2
# 9                             Cosiq                2
# 11                           Bummer                2
# 12                      Revamp Moto                2
# 15                      Skippi Pops                5
# 18               Raising Superstars                2
# 21                     Beyond Snack                2
# 22   Vivalyf Innovations- Easy Life                2
# 24                            Altor                2
# 25                            Ariro                2
# 27                          Nuutjob                3
# 28                         Meatyour                3
# 29                        EventBeep                3
# 32                            Farda                2
# 35                             LOKA                3
# ...

# %%
df[['episode_number','deal_offered']]

# %%
df.loc[[50]]
# Out:
#     episode_number  startup_number     brand_name description  deal_offered  \
# 50              17              51  Aas Vidyalaya  EdTech App             1
#
#     startup_ask_amount_lakhs  startup_ask_percentage  startup_ask_valuation  \
# 50                     150.0                     3.0                 5000.0
#
#     deal_amount_lakhs  deal_equity  ...  ghazal_invested  namita_present  \
# 50              150.0         15.0  ...                0               1
#
#     namita_invested  peyush_present  peyush_invested  vineeta_present  \
# 50                1               1                1                0
#
#     vineeta_invested  sharks_offering  amount_per_shark  equity_per_shark
# 50                 0                3              50.0               5.0
#
# [1 rows x 32 columns]

# %% [markdown]
# ### Number of offerings in which 3 and more than 3 and less than 6 sharks involved

# %%
df[(df.sharks_offering>=3) & (df.sharks_offering<=5)].shape[0]
# Out:
# 24

# %%
(df.query('sharks_offering>=3')) & (df.query('sharks_offering<=5'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19840/3597815483.py in <module>
# ----> 1 (df.query('sharks_offering>=3')) & (df.query('sharks_offering<=5'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
# ...

# %%
df.brand_name.nunique()
# Out:
# 121

# %%
df.brand_name.unique()
# Out:
# array(['BluePine Industries', 'Booz scooters', 'Heart up my Sleeves',
#        'Tagz Foods', 'Head and Heart', 'Agro tourism', 'Qzense Labs',
#        'Peeschute', 'NOCD', 'Cosiq', 'JhaJi Achaar', 'Bummer',
#        'Revamp Moto', 'Hungry Heads', 'Shrawani Engineers', 'Skippi Pops',
#        'Menstrupedia', 'Hecolll', 'Raising Superstars', 'Torch-it',
#        'La Kheer Deli', 'Beyond Snack', 'Vivalyf Innovations- Easy Life',
#        'Motion Breeze', 'Altor', 'Ariro', 'Kabira Handmade', 'Nuutjob',
#        'Meatyour', 'EventBeep', "Gopal's 56", 'ARRCOAT Surface Textures',
#        'Farda', 'Auli Lifestyle', 'SweeDesi', 'LOKA', 'Annie',
#        'Caragreen', 'The Yarn Bazaar', 'The Renal Project',
#        'Morikko Pure Foods', 'Good Good Piggy Bank', 'Hammer Lifestyle',
#        'PNT', 'Cocofit', 'Bamboo India', 'Flying Furr', 'Beyond Water',
#        "Let's Try", 'Find Your Kicks India', 'Aas Vidyalaya', 'Outbox',
# ...

# %% [markdown]
# ### what is the maximum starup ask amount

# %%
max_amount=df.startup_ask_amount_lakhs.nlargest(1)
max_amount
# Out:
# 30    30000.0
# Name: startup_ask_amount_lakhs, dtype: float64

# %%
df[['brand_name','startup_ask_amount_lakhs']]
# Out:
#               brand_name  startup_ask_amount_lakhs
# 0    BluePine Industries                      50.0
# 1          Booz scooters                      40.0
# 2    Heart up my Sleeves                      25.0
# 3             Tagz Foods                      70.0
# 4         Head and Heart                      50.0
# ..                   ...                       ...
# 116         Elcare India                     100.0
# 117             Sneakare                      20.0
# 118         French Crown                     150.0
# 119       Store My Goods                     100.0
# 120             Devnagri                     100.0
#
# [121 rows x 2 columns]

# %%
final_deal=df[df.brand_name=='Hammer Lifestyle']

# %%
final_deal.deal_amount_lakhs
# Out:
# 42    100.0
# Name: deal_amount_lakhs, dtype: float64

# %% [markdown]
# ### which shark is present in how much episodes

# %%
all_sharks = df[['rannvijay_present', 'abish_present', 'aman_present', 'anupam_present', 'ashneer_present','ghazal_present', 'namita_present', 'peyush_present','vineeta_present']]

# %%
all_sharks.sum()
# Out:
# rannvijay_present    117
# abish_present          4
# aman_present         102
# anupam_present       121
# ashneer_present       98
# ghazal_present        26
# namita_present       110
# peyush_present        92
# vineeta_present       70
# dtype: int64

# %%
shark_invest.sum()
# Out:
# aman_invested       29
# anupam_invested     24
# ashneer_invested    21
# ghazal_invested      7
# namita_invested     24
# peyush_invested     28
# vineeta_invested    16
# dtype: int64

# %%
df[['brand_name','ghazal_invested']]
# Out:
#               brand_name  ghazal_invested
# 0    BluePine Industries                0
# 1          Booz scooters                0
# 2    Heart up my Sleeves                0
# 3             Tagz Foods                0
# 4         Head and Heart                0
# ..                   ...              ...
# 116         Elcare India                0
# 117             Sneakare                0
# 118         French Crown                0
# 119       Store My Goods                0
# 120             Devnagri                0
#
# [121 rows x 2 columns]

# %% [markdown]
# ### Shark Ghazal investment in which brands

# %%
ghazal_invested=df[df.ghazal_invested==1]

# %%
ghazal_invested[['brand_name','deal_amount_lakhs']]
# Out:
#                    brand_name  deal_amount_lakhs
# 75               The Sass Bar           50.00000
# 79        Sunfox Technologies          100.00000
# 85         Watt Technovations            0.00101
# 88                   Humpy A2          100.00000
# 90   Gold Safe Solutions Ind.           50.00000
# 91                Wakao Foods           75.00000
# 110        Nomad Food Project           40.00000

# %%
plt.bar(ghazal_invested.brand_name,ghazal_invested.deal_amount_lakhs)
# Out:
# <BarContainer object of 7 artists>
